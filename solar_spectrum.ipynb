# %% [markdown]
# <a href="https://colab.research.google.com/github/ymasada/shear_dynamo.py/blob/main/solar_spectrum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import matplotlib.pyplot as plt

drive.mount('/content/drive')
f=open('/content/solar.dat','rt')

x = []; y = []
for line in f:
    data = line[:-1].split('\t')
    x.append(float(data[0]))
    y.append(float(data[1]))

plt.plot(x,y,color='black')
plt.xscale('log')
plt.yscale('log')
plt.title('Solar Spectrum')
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
